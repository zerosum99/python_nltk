# %% [markdown]
# # 형태소 분석
#
#
#     형태소 분석이란 어근, 접두사/접미사, 품사(POS, part-of-speech) 등 다양한 언어적 속성의 구조를 파악하는 작업이다.
#     구체적으로는 다음과 같은 작업으로 나뉜다.
#
#     stemming (어근 추출)
#     lemmatizing (원형 복원)
#     POS tagging (품사 태깅)

# %% [markdown]
# # pos tag 처리

# %%
import nltk.tag
import re

for i in dir(nltk.tag) :
    if re.match("[A-Z].+",i) :
        print(i)
# Out:
# AffixTagger
# BigramTagger
# BrillTagger
# BrillTaggerTrainer
# CRFTagger
# ClassifierBasedPOSTagger
# ClassifierBasedTagger
# ContextTagger
# DefaultTagger
# HiddenMarkovModelTagger
# HiddenMarkovModelTrainer
# HunposTagger
# NgramTagger
# PerceptronTagger
# RUS_PICKLE
# RegexpTagger
# SennaChunkTagger
# SennaNERTagger
# SennaTagger
# SequentialBackoffTagger
# StanfordNERTagger
# StanfordPOSTagger
# StanfordTagger
# TaggerI
# TnT
# TrigramTagger
# UnigramTagger

# %%
import nltk.tag
import re

for i in dir(nltk.tag) :
    if re.match("[a-z].+",i) :
        print(i)
# Out:
# api
# brill
# brill_trainer
# crf
# find
# hmm
# hunpos
# load
# map_tag
# mapping
# perceptron
# pos_tag
# pos_tag_sents
# print_function
# senna
# sequential
# stanford
# str2tuple
# tagset_mapping
# tnt
# tuple2str
# untag
# util

# %% [markdown]
# ## 실제 pos 약어 이름

# %%
from IPython.display import Image
Image(filename='pos.png')

# %% [markdown]
# ###  기존적인 tagging 처리 및 help
#
#     – CC = coordinaCng conjuncCon
#     – RB = adverb
#     – IN = preposiCon
#     – NN = noun
#     – JJ = adjecCve

# %% [markdown]
# ## 실제 토큰화한 후에 각 토큰에 대한 품사를 붙이기.

# %%
text = nltk.word_tokenize("And now for something completely different") 
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %% [markdown]
# ##  품사에 대힌 정보 조회

# %%
import nltk
for tag in ['CC','CD','DT','EX','FW','IN','JJ','JJR','JJS','LS','MD','NN','NNP',
            'NNPS','NNS', 'PDT', 'POS','PRP', 'PRP$','RB', 'RBR', 'RBS', 'RP','To',
            'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP','VBZ','WDT','WPS' ]:
    nltk.help.upenn_tagset(tag)
# Out:
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# ...

# %% [markdown]
# ### 문장을 토큰화 한 후에 단어별로 pos tagging 하기
#
#     문장을 분리한 후에 단어로 나눈 후에 품사들을 처리

# %%
import nltk
from nltk.tokenize import PunktSentenceTokenizer
 
document = 'Whether you\'re new to programming or an experienced developer, it\'s easy to learn and use Python.'
sentences = nltk.sent_tokenize(document)   
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('Whether', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('new', 'JJ'), ('to', 'TO'), ('programming', 'VBG'), ('or', 'CC'), ('an', 'DT'), ('experienced', 'JJ'), ('developer', 'NN'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('easy', 'JJ'), ('to', 'TO'), ('learn', 'VB'), ('and', 'CC'), ('use', 'VB'), ('Python', 'NNP'), ('.', '.')]

# %% [markdown]
# ## 명사들만 추출해서 출력

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
 
document = '''Today the Netherlands celebrates King\'s Day. To honor this tradition, 
the Dutch embassy in San Francisco invited me to'''

sentences = nltk.sent_tokenize(document)   
 
data = []
for sent in sentences:
    data = data + nltk.pos_tag(nltk.word_tokenize(sent))
    
print(data)  

for word in data: 
    if 'NNP' in word[1]: 
        print(word)
# Out:
# [('Today', 'NN'), ('the', 'DT'), ('Netherlands', 'NNP'), ('celebrates', 'VBZ'), ('King', 'NNP'), ("'s", 'POS'), ('Day', 'NNP'), ('.', '.'), ('To', 'TO'), ('honor', 'VB'), ('this', 'DT'), ('tradition', 'NN'), (',', ','), ('the', 'DT'), ('Dutch', 'JJ'), ('embassy', 'NN'), ('in', 'IN'), ('San', 'NNP'), ('Francisco', 'NNP'), ('invited', 'VBD'), ('me', 'PRP'), ('to', 'TO')]
# ('Netherlands', 'NNP')
# ('King', 'NNP')
# ('Day', 'NNP')
# ('San', 'NNP')
# ('Francisco', 'NNP')

# %% [markdown]
# ## 토큰에 대한 품사를 달고 이를 제거하기

# %%
from nltk.tag import pos_tag
tagged_list = pos_tag(word_tokenize(document))
tagged_list
# Out:
# [('Today', 'NN'),
#  ('the', 'DT'),
#  ('Netherlands', 'NNP'),
#  ('celebrates', 'VBZ'),
#  ('King', 'NNP'),
#  ("'s", 'POS'),
#  ('Day', 'NNP'),
#  ('.', '.'),
#  ('To', 'TO'),
#  ('honor', 'VB'),
#  ('this', 'DT'),
#  ('tradition', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Dutch', 'JJ'),
#  ('embassy', 'NN'),
#  ('in', 'IN'),
#  ('San', 'NNP'),
#  ('Francisco', 'NNP'),
#  ('invited', 'VBD'),
#  ('me', 'PRP'),
#  ('to', 'TO')]

# %%
from nltk.tag import untag
untag(tagged_list)
# Out:
# ['Today',
#  'the',
#  'Netherlands',
#  'celebrates',
#  'King',
#  "'s",
#  'Day',
#  '.',
#  'To',
#  'honor',
#  'this',
#  'tradition',
#  ',',
#  'the',
#  'Dutch',
#  'embassy',
#  'in',
#  'San',
#  'Francisco',
#  'invited',
#  'me',
#  'to']

# %% [markdown]
# ## tagging 결과에 대해 문자열과 튜플로 변환

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")

tuple_ = nltk.pos_tag(text)

# %%
a = nltk.tag.tuple2str(tuple_[0])
print(a)
# Out:
# They/PRP

# %%
tagged_token = nltk.tag.str2tuple(a)
tagged_token
# Out:
# ('They', 'PRP')

# %% [markdown]
# ##  정규표현식으로 tag를 달고 처리하기

# %%
tokens = 'Thieves leave young athletes in the dark'.split();
default_tagger = nltk.DefaultTagger('NN')
default_tagger.tag(tokens)
# Out:
# [('Thieves', 'NN'),
#  ('leave', 'NN'),
#  ('young', 'NN'),
#  ('athletes', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('dark', 'NN')]

# %%
patterns = [
    (r'.*ing$', 'VBG'),               # gerunds
    (r'.*ed$', 'VBD'),                # simple past
    (r'.*es$', 'VBZ'),                # 3rd singular present
    (r'.*ould$', 'MD'),               # modals
    (r'.*\'s$', 'NN$'),               # possessive noun
    (r'.*s$', 'NNS'),                 # plural nouns
    (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal num.
    (r'.*', 'NN')                     # nouns (default)
]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.tag(text)
# Out:
# [('They', 'NN'),
#  ('refuse', 'NN'),
#  ('to', 'NN'),
#  ('permit', 'NN'),
#  ('us', 'NNS'),
#  ('to', 'NN'),
#  ('obtain', 'NN'),
#  ('the', 'NN'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %% [markdown]
# ## unigramtagger 처리

# %%
from nltk.corpus import brown
from nltk.tag import UnigramTagger
test_sent = brown.sents(categories='news')[0]

print(test_sent)

unigram_tagger = UnigramTagger(brown.tagged_sents(categories='news')[:500])

print(unigram_tagger)

for tok, tag in unigram_tagger.tag(test_sent):
    print("(%s, %s), " % (tok, tag))
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# <UnigramTagger: size=2946>
# (The, AT),
# (Fulton, NP-TL),
# (County, NN-TL),
# (Grand, JJ-TL),
# (Jury, NN-TL),
# (said, VBD),
# (Friday, NR),
# (an, AT),
# (investigation, NN),
# (of, IN),
# (Atlanta's, NP$),
# (recent, JJ),
# (primary, NN),
# (election, NN),
# (produced, VBD),
# (``, ``),
# (no, AT),
# (evidence, NN),
# ('', ''),
# (that, CS),
# (any, DTI),
# (irregularities, NNS),
# (took, VBD),
# (place, NN),
# (., .),

# %% [markdown]
# #  brown corpus를 기준으로 해서 tag 처리

# %%
brown.tagged_sents(categories='news')
# Out:
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atla
# ...

# %%
unigram_tagger = UnigramTagger(brown.tagged_sents(categories='news')[:10])

unigram_tagger.encode_json_obj()[0]
# Out:
# {"''": "''",
#  ',': ',',
#  '.': '.',
#  'Allen': 'NP',
#  'Atlanta': 'NP-TL',
#  "Atlanta's": 'NP$',
#  'City': 'NN-TL',
#  'Committee': 'NN-TL',
#  'County': 'NN-TL',
#  'Court': 'NN-TL',
#  'Department': 'NN-TL',
#  'Durwood': 'NP',
#  'Executive': 'JJ-TL',
#  'Friday': 'NR',
#  'Fulton': 'NP-TL',
#  "Georgia's": 'NP$',
#  'Grand': 'JJ-TL',
#  'However': 'WRB',
#  'It': 'PPS',
#  'Ivan': 'NP',
#  'Jr.': 'NP',
#  'Judge': 'NN-TL',
#  'Jury': 'NN-TL',
#  'Mayor-nominate': 'NN-TL',
#  'Merger': 'NN-HL',
#  'Only': 'RB',
#  'Purchasing': 'VBG-TL',
#  'Pye': 'NP',
#  'September-October': 'NP',
#  'Superior': 'JJ-TL',
#  'The': 'AT',
#  '``': '``',
#  'a': 'AT',
#  'accepted': 'VBN',
#  'achieve': 'VB',
#  'act': 'VB',
#  'administration': 'NN',
#  'ambiguous': 'JJ',
#  'among': 'IN',
#  'an': 'AT',
#  'and': 'CC',
#  'any': 'DTI',
#  'are': 'BER',
#  'as': 'CS',
#  'be': 'BE',
#  'been': 'BEN',
#  'believes': 'VBZ',
#  'best': 'JJT',
#  'both': 'ABX',
#  'by': 'IN',
# ...

# %% [markdown]
# # tweets sample을 이용해서 tagged 처리하기

# %%
from nltk.corpus import twitter_samples

twitter_samples.fileids()
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
twitter_samples.strings('tweets.20150430-223406.json')[:3]
# Out:
# ['RT @KirkKus: Indirect cost of the UK being in the EU is estimated to be costing Britain £170 billion per year! #BetterOffOut #UKIP',
#  'VIDEO: Sturgeon on post-election deals http://t.co/BTJwrpbmOY',
#  'RT @LabourEoin: The economy was growing 3 times faster on the day David Cameron became Prime Minister than it is today.. #BBCqt http://t.co…']

# %%
from nltk.corpus import twitter_samples

tweets = twitter_samples.strings('positive_tweets.json')

tweets[:1]
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)']

# %%
from nltk.corpus import twitter_samples
from nltk.tag import pos_tag_sents

tweets = twitter_samples.strings('positive_tweets.json')
tweets_tokens = twitter_samples.tokenized('positive_tweets.json')

print(tweets_tokens[:1])
# Out:
# [['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)']]

# %%
tweets_tagged = pos_tag_sents(tweets_tokens)

# %% [markdown]
# ### 문장별로 조회하기

# %%
tweets_tagged[0]
# Out:
# [('#FollowFriday', 'JJ'),
#  ('@France_Inte', 'NNP'),
#  ('@PKuchly57', 'NNP'),
#  ('@Milipol_Paris', 'NNP'),
#  ('for', 'IN'),
#  ('being', 'VBG'),
#  ('top', 'JJ'),
#  ('engaged', 'VBN'),
#  ('members', 'NNS'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('community', 'NN'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  (':)', 'NN')]

# %%
tweets_tagged[1]
# Out:
# [('@Lamb2ja', 'NN'),
#  ('Hey', 'NNP'),
#  ('James', 'NNP'),
#  ('!', '.'),
#  ('How', 'NNP'),
#  ('odd', 'JJ'),
#  (':/', 'NNP'),
#  ('Please', 'NNP'),
#  ('call', 'VB'),
#  ('our', 'PRP$'),
#  ('Contact', 'NNP'),
#  ('Centre', 'NNP'),
#  ('on', 'IN'),
#  ('02392441234', 'CD'),
#  ('and', 'CC'),
#  ('we', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('assist', 'VB'),
#  ('you', 'PRP'),
#  (':)', 'VBP'),
#  ('Many', 'JJ'),
#  ('thanks', 'NNS'),
#  ('!', '.')]

# %% [markdown]
# ### 실제 내부의 품사별로 계산하기

# %%
JJ_count = 0
NN_count = 0

for tweet in tweets_tagged:
    for pair in tweet:
        tag = pair[1]
        if tag == 'JJ':
            JJ_count += 1

        elif tag == 'NN':
            NN_count += 1
            
print(JJ_count, NN_count)
# Out:
# 6094 13180

# %% [markdown]
# # 단어들에 대한 빈도 계산하기 : FreqDist

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
from nltk import *

# %%
print(type(text1))

print(text1.__class__.__bases__)

print(text1)
# Out:
# <class 'nltk.text.Text'>
# (<class 'object'>,)
# <Text: Moby Dick by Herman Melville 1851>

# %%
print(text1.name)
print(text1.common_contexts('Moby'))
# Out:
# Moby Dick by Herman Melville 1851
# ('The following word(s) were not found:', 'm o b y')
# None

# %%
fdist1 = FreqDist(text1)

# %%
fdist1.__class__.__bases__
# Out:
# (collections.Counter,)

# %%
fdist1.most_common(10)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]
